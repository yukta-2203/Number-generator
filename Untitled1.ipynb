# %% [markdown]
# <a href="https://colab.research.google.com/github/yukta-2203/Number-generator/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ASSIGNMENT 03 DHV
# YUKTA
# 2023UCD2124

# %% [markdown]
# Predict the monthly rent of a house/apartment using linear regression

# %% [markdown]
# data preprocessing

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('House_Rent_Dataset.csv')

# %%
df.isnull().sum()
# Out:
# Posted On            0
# BHK                  0
# Rent                 0
# Size                 0
# Floor                0
# Area Type            0
# Area Locality        0
# City                 0
# Furnishing Status    0
# Tenant Preferred     0
# Bathroom             0
# Point of Contact     0
# dtype: int64

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %%
df.head()
# Out:
#     Posted On  BHK   Rent  Size            Floor    Area Type  \
# 0  2022-05-18    2  10000  1100  Ground out of 2   Super Area
# 1  2022-05-13    2  20000   800       1 out of 3   Super Area
# 2  2022-05-16    2  17000  1000       1 out of 3   Super Area
# 3  2022-07-04    2  10000   800       1 out of 2   Super Area
# 4  2022-05-09    2   7500   850       1 out of 2  Carpet Area
#
#               Area Locality     City Furnishing Status  Tenant Preferred  \
# 0                    Bandel  Kolkata       Unfurnished  Bachelors/Family
# 1  Phool Bagan, Kankurgachi  Kolkata    Semi-Furnished  Bachelors/Family
# 2   Salt Lake City Sector 2  Kolkata    Semi-Furnished  Bachelors/Family
# 3               Dumdum Park  Kolkata       Unfurnished  Bachelors/Family
# 4             South Dum Dum  Kolkata       Unfurnished         Bachelors
#
#    Bathroom Point of Contact
# 0         2    Contact Owner
# 1         1    Contact Owner
# 2         1    Contact Owner
# 3         1    Contact Owner
# ...

# %%
df=df.drop(columns=['Posted On'],axis=1)

# %%
def wisker(df, col):
    q1,q3=np.percentile(df[col],[25,75])
    iqr=q3-q1
    lw=q1-1.5*iqr
    uw=q3+1.5*iqr
    return lw,uw

# %%
for i in ['BHK','Rent','Size','Bathroom']:
  lw,uw=wisker(df, i)
  df[i]=np.where(df[i]<lw,lw,df[i])
  df[i]=np.where(df[i]>uw,uw,df[i])

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %%
df.duplicated().sum()
# Out:
# np.int64(10)

# %%
df.drop(columns='Floor')
# Out:
#       BHK     Rent    Size    Area Type             Area Locality       City  \
# 0     2.0  10000.0  1100.0   Super Area                    Bandel    Kolkata
# 1     2.0  20000.0   800.0   Super Area  Phool Bagan, Kankurgachi    Kolkata
# 2     2.0  17000.0  1000.0   Super Area   Salt Lake City Sector 2    Kolkata
# 3     2.0  10000.0   800.0   Super Area               Dumdum Park    Kolkata
# 4     2.0   7500.0   850.0  Carpet Area             South Dum Dum    Kolkata
# ...   ...      ...     ...          ...                       ...        ...
# 4741  2.0  15000.0  1000.0  Carpet Area              Bandam Kommu  Hyderabad
# 4742  3.0  29000.0  2000.0   Super Area      Manikonda, Hyderabad  Hyderabad
# 4743  3.0  35000.0  1750.0  Carpet Area      Himayath Nagar, NH 7  Hyderabad
# 4744  3.0  45000.0  1500.0  Carpet Area                Gachibowli  Hyderabad
# 4745  2.0  15000.0  1000.0  Carpet Area           Suchitra Circle  Hyderabad
#
# ...

# %%
df.sample(5)
# Out:
#       BHK     Rent    Size            Floor    Area Type  \
# 4489  2.0  15000.0  1250.0       3 out of 4  Carpet Area
# 3295  1.0  10000.0   675.0       2 out of 2   Super Area
# 1768  1.0   4500.0   600.0  Ground out of 3   Super Area
# 1419  1.0  25000.0   400.0     18 out of 23  Carpet Area
# 2798  2.0  22000.0  1000.0       4 out of 5   Super Area
#
#                             Area Locality       City Furnishing Status  \
# 4489                 Himayath Nagar, NH 7  Hyderabad    Semi-Furnished
# 3295                             Perambur    Chennai       Unfurnished
# 1768  Peenya Industrial Area, Tumkur Road  Bangalore       Unfurnished
# 1419                                Worli     Mumbai       Unfurnished
# 2798                          Vasant Kunj      Delhi    Semi-Furnished
#
#       Tenant Preferred  Bathroom Point of Contact
# 4489         Bachelors       2.0    Contact Owner
# 3295  Bachelors/Family       1.0    Contact Owner
# ...

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
numerical_features = ['BHK', 'Size', 'Bathroom']
categorical_features = ['Area Type', 'Furnishing Status', 'Tenant Preferred', 'City']

transformer = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numerical_features),
        ('cat', OneHotEncoder(handle_unknown='ignore'), categorical_features)
    ],
    remainder='passthrough'
)

# %%
X_transformed = transformer.fit_transform(df)

# %%
df.head()
# Out:
#    BHK     Rent    Size            Floor    Area Type  \
# 0  2.0  10000.0  1100.0  Ground out of 2   Super Area
# 1  2.0  20000.0   800.0       1 out of 3   Super Area
# 2  2.0  17000.0  1000.0       1 out of 3   Super Area
# 3  2.0  10000.0   800.0       1 out of 2   Super Area
# 4  2.0   7500.0   850.0       1 out of 2  Carpet Area
#
#               Area Locality     City Furnishing Status  Tenant Preferred  \
# 0                    Bandel  Kolkata       Unfurnished  Bachelors/Family
# 1  Phool Bagan, Kankurgachi  Kolkata    Semi-Furnished  Bachelors/Family
# 2   Salt Lake City Sector 2  Kolkata    Semi-Furnished  Bachelors/Family
# 3               Dumdum Park  Kolkata       Unfurnished  Bachelors/Family
# 4             South Dum Dum  Kolkata       Unfurnished         Bachelors
#
#    Bathroom Point of Contact
# 0       2.0    Contact Owner
# 1       1.0    Contact Owner
# 2       1.0    Contact Owner
# 3       1.0    Contact Owner
# 4       1.0    Contact Owner

# %%
df.head()
# Out:
#    BHK     Rent    Size            Floor    Area Type  \
# 0  2.0  10000.0  1100.0  Ground out of 2   Super Area
# 1  2.0  20000.0   800.0       1 out of 3   Super Area
# 2  2.0  17000.0  1000.0       1 out of 3   Super Area
# 3  2.0  10000.0   800.0       1 out of 2   Super Area
# 4  2.0   7500.0   850.0       1 out of 2  Carpet Area
#
#               Area Locality     City Furnishing Status  Tenant Preferred  \
# 0                    Bandel  Kolkata       Unfurnished  Bachelors/Family
# 1  Phool Bagan, Kankurgachi  Kolkata    Semi-Furnished  Bachelors/Family
# 2   Salt Lake City Sector 2  Kolkata    Semi-Furnished  Bachelors/Family
# 3               Dumdum Park  Kolkata       Unfurnished  Bachelors/Family
# 4             South Dum Dum  Kolkata       Unfurnished         Bachelors
#
#    Bathroom Point of Contact
# 0       2.0    Contact Owner
# 1       1.0    Contact Owner
# 2       1.0    Contact Owner
# 3       1.0    Contact Owner
# 4       1.0    Contact Owner

# %%
df.head()
# Out:
#    BHK     Rent    Size            Floor    Area Type  \
# 0  2.0  10000.0  1100.0  Ground out of 2   Super Area
# 1  2.0  20000.0   800.0       1 out of 3   Super Area
# 2  2.0  17000.0  1000.0       1 out of 3   Super Area
# 3  2.0  10000.0   800.0       1 out of 2   Super Area
# 4  2.0   7500.0   850.0       1 out of 2  Carpet Area
#
#               Area Locality     City Furnishing Status  Tenant Preferred  \
# 0                    Bandel  Kolkata       Unfurnished  Bachelors/Family
# 1  Phool Bagan, Kankurgachi  Kolkata    Semi-Furnished  Bachelors/Family
# 2   Salt Lake City Sector 2  Kolkata    Semi-Furnished  Bachelors/Family
# 3               Dumdum Park  Kolkata       Unfurnished  Bachelors/Family
# 4             South Dum Dum  Kolkata       Unfurnished         Bachelors
#
#    Bathroom Point of Contact
# 0       2.0    Contact Owner
# 1       1.0    Contact Owner
# 2       1.0    Contact Owner
# 3       1.0    Contact Owner
# 4       1.0    Contact Owner

# %%
df = df.drop(columns='Floor')

# %%
df.head()
# Out:
#    BHK     Rent    Size    Area Type             Area Locality     City  \
# 0  2.0  10000.0  1100.0   Super Area                    Bandel  Kolkata
# 1  2.0  20000.0   800.0   Super Area  Phool Bagan, Kankurgachi  Kolkata
# 2  2.0  17000.0  1000.0   Super Area   Salt Lake City Sector 2  Kolkata
# 3  2.0  10000.0   800.0   Super Area               Dumdum Park  Kolkata
# 4  2.0   7500.0   850.0  Carpet Area             South Dum Dum  Kolkata
#
#   Furnishing Status  Tenant Preferred  Bathroom Point of Contact
# 0       Unfurnished  Bachelors/Family       2.0    Contact Owner
# 1    Semi-Furnished  Bachelors/Family       1.0    Contact Owner
# 2    Semi-Furnished  Bachelors/Family       1.0    Contact Owner
# 3       Unfurnished  Bachelors/Family       1.0    Contact Owner
# 4       Unfurnished         Bachelors       1.0    Contact Owner

# %%
df.head()
# Out:
#    BHK     Rent    Size    Area Type             Area Locality     City  \
# 0  2.0  10000.0  1100.0   Super Area                    Bandel  Kolkata
# 1  2.0  20000.0   800.0   Super Area  Phool Bagan, Kankurgachi  Kolkata
# 2  2.0  17000.0  1000.0   Super Area   Salt Lake City Sector 2  Kolkata
# 3  2.0  10000.0   800.0   Super Area               Dumdum Park  Kolkata
# 4  2.0   7500.0   850.0  Carpet Area             South Dum Dum  Kolkata
#
#   Furnishing Status  Tenant Preferred  Bathroom Point of Contact
# 0       Unfurnished  Bachelors/Family       2.0    Contact Owner
# 1    Semi-Furnished  Bachelors/Family       1.0    Contact Owner
# 2    Semi-Furnished  Bachelors/Family       1.0    Contact Owner
# 3       Unfurnished  Bachelors/Family       1.0    Contact Owner
# 4       Unfurnished         Bachelors       1.0    Contact Owner

# %%
df = pd.get_dummies(df, columns=['Area Type', 'Furnishing Status', 'Tenant Preferred', 'City', 'Point of Contact'])

# %%
df.head()
# Out:
#    BHK     Rent    Size  Bathroom  Area Type_Built Area  \
# 0  2.0  10000.0  1100.0       2.0                 False
# 1  2.0  20000.0   800.0       1.0                 False
# 2  2.0  17000.0  1000.0       1.0                 False
# 3  2.0  10000.0   800.0       1.0                 False
# 4  2.0   7500.0   850.0       1.0                 False
#
#    Area Type_Carpet Area  Area Type_Super Area  Furnishing Status_Furnished  \
# 0                  False                  True                        False
# 1                  False                  True                        False
# 2                  False                  True                        False
# 3                  False                  True                        False
# 4                   True                 False                        False
#
#    Furnishing Status_Semi-Furnished  Furnishing Status_Unfurnished  ...  \
# 0                             False                           True  ...
# ...

# %%
if 'Tenant Preferred_Family' in df.columns:
  df = df.drop(columns=['Tenant Preferred_Family'], axis=1)
elif 'Tenant Preferred_Bachelors' in df.columns:
  df = df.drop(columns=['Tenant Preferred_Bachelors'], axis=1)

# %%
df.head()
# Out:
#    BHK     Rent    Size  Bathroom  Area Type_Built Area  \
# 0  2.0  10000.0  1100.0       2.0                 False
# 1  2.0  20000.0   800.0       1.0                 False
# 2  2.0  17000.0  1000.0       1.0                 False
# 3  2.0  10000.0   800.0       1.0                 False
# 4  2.0   7500.0   850.0       1.0                 False
#
#    Area Type_Carpet Area  Area Type_Super Area  Furnishing Status_Furnished  \
# 0                  False                  True                        False
# 1                  False                  True                        False
# 2                  False                  True                        False
# 3                  False                  True                        False
# 4                   True                 False                        False
#
#    Furnishing Status_Semi-Furnished  Furnishing Status_Unfurnished  ...  \
# 0                             False                           True  ...
# ...

# %%
df=df.dropna()

# %%
from sklearn.model_selection import train_test_split
X=df.drop(columns='Rent',axis=1)
y=df['Rent']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=3)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.fit_transform(X_test)

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
pred=model.predict(X_test)

# %%
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.scatter(y_test,pred)
plt.plot([y_train.min(), y_train.max()], [y_train.min(), y_train.max()], color='red', linestyle='--')
plt.xlabel("Actual Rent ")
plt.ylabel("Predicted Rent ")
plt.title("Actual vs. Predicted Rent ")



plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x=pred,y=y_test)
plt.axhline(y=0, color='r', linestyle='--')
plt.title('Residual Plot')
plt.xlabel('Predicted Values')
plt.ylabel('Residuals')
plt.grid(True)
plt.show()

# %%
import statsmodels.api as sm
residuals = y_test - pred

fig, ax = plt.subplots(figsize=(10, 6))
sm.qqplot(residuals, line='s', ax=ax)
ax.set_title('Q-Q Plot of Residuals')
plt.show()

# %%
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error,accuracy_score

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

mae = mean_absolute_error(y_test, pred)
mse = mean_squared_error(y_test, pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, pred)

# %%
mae
# Out:
# 7135.203584788253

# %%
mse
# Out:
# 96480718.11996457

# %%
rmse
# Out:
# np.float64(9822.459881311024)

# %%
r2_score
# Out:
# <function sklearn.metrics._regression.r2_score(y_true, y_pred, *, sample_weight=None, multioutput='uniform_average', force_finite=True)>

# %%
adjusted_r2_score = 1 - (1-r2)*(len(y_test)-1)/(len(y_test) - X_test.shape[1] -1)

# %%
model.coef_
# Out:
# array([ 2.87700814e+03,  5.13161987e+03,  3.18848013e+03, -1.64433294e+01,
#         2.19251234e+02, -2.18487669e+02,  1.28327152e+03, -2.45868692e+02,
#        -6.72568396e+02,  4.06149318e+02, -1.28259468e+03, -1.86632037e+03,
#         2.08064727e+02, -2.55819154e+03, -2.09622730e+03,  7.01029059e+03,
#         2.45517165e+03,  4.81416098e+00, -2.45479309e+03])

# %%
model.intercept_
# Out:
# np.float64(24421.061643835616)
